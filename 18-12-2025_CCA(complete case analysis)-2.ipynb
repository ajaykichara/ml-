# %%
# cca :--- completye case analysis  

# df --- >missing data ------->>>> fillter  missing  data  
# new_df = filtered_columns_in_which _we_have_missing_data

# new_df =  missing_data_frop

# architecture---->>>> histogram------->>>>>
# past columns  inn  which we  have missing data 
#  update  columns  in which  we  have  no  missing  data  

# if past  data architecture is  overlap  to  new data architecture 
# it means  we  drop  missing  data
# if  past data  architecture is  not overlap  to  new data architecture  --------->>>>>>
# it means  we  not drop  missing data ,we will  fill  the  missing  data

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\ml  batch  -p'

# %%
import  numpy as np 
import  pandas as  pd  
df =  pd.read_csv('C:\\Users\\Admin\\ml  batch  -p\\dsjob - dsjob.csv')

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     0.000000
# gender                    23.860968
# relevent_experience        0.000000
# enrolled_university        1.456083
# education_level            2.442461
# major_discipline          14.654767
# experience                 0.234852
# company_size              29.215594
# company_type              29.779239
# last_new_job               1.878816
# training_hours             0.000000
# dtype: float64

# %%
cols  = [var  for var in df.columns  if  df [var].isnull().mean() < 0.05 and  df[var].isnull().mean()>0]
cols
# Out:
# ['enrolled_university', 'education_level', 'experience', 'last_new_job']

# %%
df[cols].sample(5)
# Out:
#      enrolled_university education_level experience last_new_job
# 1913       no_enrollment         Masters          9           >4
# 307        no_enrollment         Masters          3            1
# 1996    Part time course        Graduate          2            1
# 1248       no_enrollment         Masters          7            1
# 1582       no_enrollment         Masters        >20           >4

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          1269
# Masters            496
# High School        222
# Phd                 54
# Primary School      36
# Name: count, dtype: int64

# %%
# len(df) numer of rows show :-
# This shows NON-MISSING data proportion
len(df[cols].dropna()) / len(df)
# Out:
# 0.9478628464067638

# %%
new_df = df[cols].dropna()
df.shape,new_df.shape
# Out:
# ((2129, 13), (2018, 4))

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# original data 
df['experience'].hist(bins=50,ax=ax,density = True ,color='red')
# data after cca ,the argument alpha make the color transparaent ,so we can 
# see the overlay of the 2 distrribution 
new_df['experience'].hist(bins=50,ax=ax,density = True ,color='green',alpha=0.8)
# Out:
# <Axes: >

# %%
# sir  give task  in covid  data   in fever columns in we  have missing values  so  we  can take  ratio 5% to 50  mean ratio  no  matter  
# we always  take  5% only  its task  so we take  up 50%

# %%
import  numpy as np  
import  pandas as  pd  
df  =  pd.read_csv('C:\\Users\\Admin\\ml  batch  -p\\covid_toy.csv')

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# age           0.0
# gender        0.0
# fever        10.0
# cough         0.0
# city          0.0
# has_covid     0.0
# dtype: float64

# %%
# this will not  show  because  fever  have  more than 5% nan so  we increse  see  down side  
# cat =  [var for var in df.columns if df[var].isnull().mean()<0.05 and  df[var].isnull().mean()>0]
# cat    

cat =  [var for var in df.columns if df[var].isnull().mean()<0.50 and  df[var].isnull().mean()>0]
cat
# Out:
# ['fever']

# %%
len(df[cat].dropna())/len(df[cat])  # we  not drop  in real  but  according to  task  we drop
# Out:
# 0.9

# %%
new_df  =  df[cat].dropna()

fig = plt.figure()
ax = fig.add_subplot(111)

df[cat].hist(bins=50,ax=ax,density=True,color='red')
new_df[cat].hist(bins=50,ax=ax,density=True,color='green',alpha=0.8)
# Out:
# array([<Axes: title={'center': 'fever'}>], dtype=object)

# %%
# now  third task  : -  titanic datat set  use  age column
# use ratio 10,20,30,40

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\ml  batch  -p'

# %%
import  numpy as  np 
import  pandas as pd  
df=  pd.read_csv('C:\\Users\\Admin\\ml  batch  -p\\titanic - titanic.csv')

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
cat = [var for var in df.columns if df[var].isnull().mean()<0.21 and df[var].isnull().mean()>0]
cat
# Out:
# ['Age', 'Fare']

# %%
len(df[cat].dropna())/len(df[cat])
# Out:
# 0.7918660287081339

# %%
new_df  =  df[cat].dropna()

fig = plt.figure()
ax = fig.add_subplot(111)

df['Age'].hist(bins=50,ax=ax,density=True,color='red')    # here we pass only 1 columns name because we use subplots for single  view 
# if 4 columns have then manullay 4 columns check 
new_df['Age'].hist(bins=50,ax=ax,density=True,color='green',alpha=0.8)   
# we can drop it
# Out:
# <Axes: >

# %%
fig = plt.figure() # Create a figure (window)
ax = fig.add_subplot(111)# Add one subplot (axes) to it

df['Fare'].hist(bins=50,ax=ax,density=True,color='red')   
new_df['Fare'].hist(bins=50,ax=ax,density=True,color='green',alpha=0.8)   
# in this we not apply cca or dropna
# Out:
# <Axes: >

# %%
 for c in cat:   #  indusrial type  use 
    df[c].hist(bins=50, alpha=0.5, label='Before')
    new_df[c].hist(bins=50, alpha=0.5, label='After')
    plt.legend() # is help to show label
    plt.title(c)
    plt.show()
